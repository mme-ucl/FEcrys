# %%
from pipeline import *

# %%
'''
the main TODO is to make a tutorial

over time this will be added

this JN is meant to show the easy-to-use setup in pipeline.py
pipeline.py is directly based/copy of project_settings.py, but adding the initial setup for a new system
this notebook is a short tutorial for how one can run everything using the PIPELINE class
further information at the current stage is in project_settings.py

this revised setup (PIPELINE class) will be tested on a new system soon, to check/fix that all parts are easy-to-use

''';

# %%
sa = PIPELINE('SA')
# Out:
# created folder: ./O/MM/molecules/SA
# created folder: ./O/MM/molecules/SA/misc
# created folder: ./O/MM/molecules/SA/temp
# created folder: ./O/MM/molecules/SA/data
# created folder: ./O/MM/molecules/SA/data/NPT
# next: please run add_single_molecule_pdb_(PDB_single_mol)
# no unit cells found

# %%
sa.add_single_molecule_pdb_('./O/MM/GAFF_sc/succinic_acid/succinic_acid_single_mol.pdb')
# Out:
# n_atoms_mol = 14
# no unit cells found
# next: please run add_unitcell_(PDB_unitcell, name_of_the_form)

# %%
sa.add_unitcell_('./O/MM/GAFF_sc/succinic_acid/succinic_acid_Ae_unitcell.pdb', 'alpha')
sa.add_unitcell_('./O/MM/GAFF_sc/succinic_acid/succinic_acid_Be_unitcell.pdb', 'beta')
sa.add_unitcell_('./O/MM/GAFF_sc/succinic_acid/succinic_acid_G_unitcell.pdb', 'gamma')
# Out:
# saved: ./O/MM/molecules/SA/SA_alpha_unitcell_temp_reordered.pdb
# file saved: ./O/MM/molecules/SA/SA_alpha_unitcell.pdb
# list_forms:
#  ['alpha']
# next : please run check_create_supercells_(max_n_mol)
# saved: ./O/MM/molecules/SA/SA_beta_unitcell_temp_reordered.pdb
# file saved: ./O/MM/molecules/SA/SA_beta_unitcell.pdb
# list_forms:
#  ['beta', 'alpha']
# next : please run check_create_supercells_(max_n_mol)
# saved: ./O/MM/molecules/SA/SA_gamma_unitcell_temp_reordered.pdb
# file saved: ./O/MM/molecules/SA/SA_gamma_unitcell.pdb
# list_forms:
#  ['beta', 'gamma', 'alpha']
# next : please run check_create_supercells_(max_n_mol)

# %%
sa.add_unitcell_('./O/MM/GAFF_sc/succinic_acid/succinic_acid_G_unitcell.pdb', 'gamma')
# Out:
# add_unitcell_() : output file already found
# list_forms:
#  ['beta', 'gamma', 'alpha']
# next : please run check_create_supercells_(max_n_mol)

# %%
sa.check_unitcells_()
# Out:
# list_forms:
#  ['beta', 'gamma', 'alpha']
# True

# %%
sa.check_create_supercells_()
# Out:
# list_forms:
#  ['beta', 'gamma', 'alpha']
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell111.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell112.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell113.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell212.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell115.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell213.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell117.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell222.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell313.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell215.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell223.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell217.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell315.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell224.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell323.pdb
# saved ./O/MM/molecules/SA/SA_beta_unitcell_cell225.pdb
# ...

# %%
sa.list_n_mol_recommended
# Out:
# [4, 8, 12, 16, 20, 24, 28, 32, 36, 40]

# %%
sa.check_ideal_supercells_(8)
# Out:
# form beta with considered list_n_mol = [8, 10, 12, 14, 16, 18, 20, 24, 28, 30, 32, 36, 40]
# form gamma with considered list_n_mol = [8, 12, 16, 20, 24, 28, 32, 36, 40]
# form alpha with considered list_n_mol = [8, 10, 12, 14, 16, 18, 20, 24, 28, 30, 32, 36, 40]
# maximum PME cutoff (d_max) possible with current set of list_n_mol selections: 0.268nm

# %%
sa.check_ideal_supercells_(16)
# Out:
# form beta with considered list_n_mol = [16, 18, 20, 24, 28, 30, 32, 36, 40]
# form gamma with considered list_n_mol = [16, 20, 24, 28, 32, 36, 40]
# form alpha with considered list_n_mol = [16, 18, 20, 24, 28, 30, 32, 36, 40]
# maximum PME cutoff (d_max) possible with current set of list_n_mol selections: 0.361nm

# %%
# sa.FF_class
# AttributeError: 'PIPELINE' object has no attribute 'FF_class'

# %%
# parametrise_with_OPLS (these are the GROMACS input files from LigParGen)
sa.check_parametrise_with_OPLS_('UNK_72E4F4.gro', 'UNK_72E4F4.itp', test=True)
# Out:
# ok
# (test = True) : testing if there are any errors:
# # initialise_object (SingleComponent) with OPLS FF, from the input file (PDB):
#  ./O//MM/molecules/SA/SA_single_mol.pdb
# n_molecules: 1
# !! warning : this method is not robust, please check .pdb outputs from this method in VMD before using.
# no periodic clashes were found in file
# no rename
# (1,14,3)
# saved: /mnt/c/Users/User/Desktop/FEcrys/O/MM/molecules/SA/misc/OPLS_single_mol_SA.pdb
# first time running OPLS_general for this moelcule? setting permuation in case needed:
# forward permutation works: True
# inverse permatation works: True
# saved /mnt/c/Users/User/Desktop/FEcrys/O/MM/molecules/SA/misc/OPLS_single_mol_permutations_SA
# ! using OPLS ff with permuation of atoms turned ON.
# 'permuation of atoms turned ON' -> to reduce cost during run_simulation_ the method for saving xyz frames is slightly adjusted
#
# # initialise_system:
# ! only one molecule in the system, setting non-bonded method to app.NoCutoff
# ...

# %%
sa.set_FF_(OPLS_general)
# Out:
# checking forcefield is set up
# ok
# molecule with 14 atoms, of which 8 are heavy atoms, and the rest are 6 hydrogens.

# %%
sa.FF_class
# Out:
# O.MM.ff_setup.OPLS_general

# %%
# parametrise_with_GAFF_automatic_
# sa.parametrise_with_GAFF_automatic_(test=True)
sa.set_FF_(GAFF) # can set straight away
# Out:
# checking forcefield is set up
# # initialise_object (SingleComponent) with GAFF FF, from the input file (PDB):
#  ./O//MM/molecules/SA/SA_single_mol.pdb
# n_molecules: 1
# generating tleap inputs for this molecule:
# !! warning : this method is not robust, please check .pdb outputs from this method in VMD before using.
# no periodic clashes were found in file
# no rename
# (1,14,3)
# saved: /mnt/c/Users/User/Desktop/FEcrys/O/MM/molecules/SA/misc/SA_single_mol.pdb
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to gaff; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for pdb File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
#    Status: pass
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# ...

# %%
sa.FF_class
# Out:
# O.MM.sc_system.GAFF

# %%
sa.list_forms
# Out:
# ['beta', 'gamma', 'alpha']

# %%
sa.list_n_mol_recommended
# Out:
# [4, 8, 12, 16, 20, 24, 28, 32, 36, 40]

# %%
dict(zip(sa.list_forms,[16]*3))
# Out:
# {'beta': 16, 'gamma': 16, 'alpha': 16}

# %%
sa.check_ideal_supercells_(16)
sa.set_d_cut_(0.36) # 0.36nm ; 'd_cut' = 'PME_cutoff' in project_settings.py
# Out:
# form beta with considered list_n_mol = [16, 18, 20, 24, 28, 30, 32, 36, 40]
# form gamma with considered list_n_mol = [16, 20, 24, 28, 32, 36, 40]
# form alpha with considered list_n_mol = [16, 18, 20, 24, 28, 30, 32, 36, 40]
# maximum PME cutoff (d_max) possible with current set of list_n_mol selections: 0.361nm

# %%
sa.d_cut
# Out:
# 0.36

# %%
# AssertionError: please set_ind_rO_
#plot_mol_larger_(sa.IC.mol)
sa.IC.mol

# %%
sa.set_ind_rO_(4) # the black dot on the figure

# %%
sa.ind_rO
# Out:
# 4

# %%
# AssertionError: please set_d_cut_
# AssertionError: please set_ind_rO_

sa.NPT_(_list_forms = sa.list_forms,
        _Ts = [300],
        _list_n_mol = dict(zip(sa.list_forms,[[16]]*3)),
        NPT_subfolder = '',
        T_init = None,
        n_frames_warmup = 0,#5000,
        n_frames_sample = 10,#100000,
        n_frames_stride = 50,
        save_equilibrated_supercell = True,
       )
# Out:
# NPT simulation initialised from ideal supercell
# starting NPT simulation: form=gamma, cell=[2, 2, 1] (n_mol=16), T=300, FF=GAFF
# dataset: ./O/MM/molecules/SA/data/NPT//SA_gaff_NPT_dataset_form_gamma_Cell_221_Temp_300_lr0.36
#
#  starting trajectory, this will be saved into folder ./O/MM/molecules/SA/data/NPT/
#
# # initialise_object (SingleComponent) with GAFF FF, from the input file (PDB):
#  ./O//MM/molecules/SA/SA_gamma_unitcell_cell221.pdb
# n_molecules: 16
#
# # initialise_system:
# set PME cutoff to: 0.36 nm
# removeCMMotion active: True
#
# __ changing n_mol in top: ________________________________
# in the /mnt/c/Users/User/Desktop/FEcrys/O/MM/molecules/SA/misc/x_SA_gmx.top
# replaced 1 line ( 165 )
#  from:
#      UNK                  1
#  to
#      UNK                  16
# these changes were written into file: /mnt/c/Users/User/Desktop/FEcrys/O/MM/molecules/SA/misc/x_x_SA_gmx.top
# __________________________________________________________
#
# ...

# %%
# checking that OPLS also runs:
sa.set_FF_(OPLS_general)
# Out:
# checking forcefield is set up
# ok
# molecule with 14 atoms, of which 8 are heavy atoms, and the rest are 6 hydrogens.

# %%
# AssertionError: please set_d_cut_
# AssertionError: please set_ind_rO_

sa.NPT_(_list_forms = sa.list_forms,
        _Ts = [300],
        _list_n_mol = dict(zip(sa.list_forms,[[16]]*3)),
        NPT_subfolder = '',
        T_init = None,
        n_frames_warmup = 0,#5000,
        n_frames_sample = 10,#100000,
        n_frames_stride = 50,
        save_equilibrated_supercell = True,
       )
# Out:
# NPT simulation initialised from ideal supercell
# starting NPT simulation: form=gamma, cell=[2, 2, 1] (n_mol=16), T=300, FF=OPLS
# dataset: ./O/MM/molecules/SA/data/NPT//SA_opls_NPT_dataset_form_gamma_Cell_221_Temp_300_lr0.36
#
#  starting trajectory, this will be saved into folder ./O/MM/molecules/SA/data/NPT/
#
# # initialise_object (SingleComponent) with OPLS FF, from the input file (PDB):
#  ./O//MM/molecules/SA/SA_gamma_unitcell_cell221.pdb
# n_molecules: 16
# ! using OPLS ff with permuation of atoms turned ON.
# this assumes all molecules in the input PDB have the same permutation as the first molecule
# 'permuation of atoms turned ON' -> to reduce cost during run_simulation_ the method for saving xyz frames is slightly adjusted
#
# # initialise_system:
# set PME cutoff to: 0.36 nm
# removeCMMotion active: True
# set SwitchingFunction to 0.95 * PME_cutoff = 0.34199999999999997 nm
# adjusted EwaldErrorTolerance from 0.0005 to 0.0001
# no corrections to self.system
# ...
