# %%
from P3_JN_helper import *

# %%
SA = P3_JN_helper('SA')
VEL = P3_JN_helper('VEL')
MIV = P3_JN_helper('MIV')

''' structure of this notebook (SA as example):
# scipts that were used for one of the systems in the paper. [show the NPT -> eqm.cell -> NVT step seperately in another JN]
##
SA.tabulate_ecm_BAR_result_()
SA.tabulate_ecm_MBAR_result_()
##
SA.plot_SI_ecm_figure_()
##
[SA.tabulate_pgm_result_by_model_(i) for i in range(SA.n_pgm_versions_involved)];
##
[SA.plot_maintext_plot_by_model_(i) for i in range(SA.n_pgm_versions_involved)];
##
[SA.plot_SI_pgm_figure_by_model_(i) for i in range(SA.n_pgm_versions_involved)];
##
SA.plot_SI_pgm_energy_overlaps_()
''';
# Out:
# succinic_acid
# veliparib
# mivebresib

# %%
SA.initialise_PGM_result_evalaution_()
VEL.initialise_PGM_result_evalaution_()
MIV.initialise_PGM_result_evalaution_()
# Out:
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# succinic_acid pgm results form model versions ['/mol', '/mol,multimap', '/2mol'] were imported
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# found saved BAR result
# ...

# %% [markdown]
# # Succinic Acid (SA)

# %%
# template of the main scripts in one of the systems:

form = 'A'
n_mol = 16

Next = 140

print(SA.script_NPT_(form,n_mol)  +'\n'+'#'*Next)
print(SA.script_NVT_(form,n_mol)  +'\n'+'#'*Next)
print(SA.script_ECM_(form,n_mol)  +'\n'+'#'*Next)
print(SA.script_PGM_(form,n_mol)  +'\n'+'#'*Next)
# Out:
#         from .O.MM.sc_system import *
#
#         # NPT script (equilibrating the ideal supercell to the forcefield):
#         # this is part of a loop, but more clear to write here as a single example
#
#         print('starting:', Ae, 222)
#         try:
#             PDB_unitcell = './O/MM/GAFF_sc/succinic_acid/succinic_acid_Ae_unitcell.pdb'
#             PDB_supercell = supercell_from_unitcell_(PDB_unitcell, cell=[2, 2, 2], save_output=True)[-1]
#             sc = SingleComponent(PDB = str(PDB_supercell), n_atoms_mol=14, name='succinic_acid', FF_name='GAFF')
#             sc.initialise_system_(PME_cutoff=0.36, nonbondedMethod=app.PME)
#             sc.initialise_simulation_(timestep_ps = 0.002, # ps
#                                     P = 1,               # atm
#                                     T = 300,             # K
#                                     barostat_type = 2,   # fully flexible
#                                     minimise = True,
# ...

# %%
SA.tabulate_ecm_BAR_result_()
SA.tabulate_ecm_MBAR_result_()
# Out:
# ECM lattice FE estimates based on BAR:
#
# form       | n_mol      | cell       | FE /kT     | SE /kT     || S /k
# ========== | ========== | ========== | ========== | ========== || ==========
# A          | 16         | 222        | -19.36     | 0.019      || -153.404
# A          | 24         | 223        | -19.025    | 0.019      || -153.893
# A          | 32         | 224        | -18.926    | 0.019      || -154.014
# ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# B          | 8          | 212        | -19.361    | 0.019      || -152.575
# B          | 16         | 222        | -18.846    | 0.019      || -153.188
# B          | 24         | 223        | -18.542    | 0.019      || -153.505
# B          | 32         | 224        | -18.423    | 0.018      || -153.595
# ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# G          | 8          | 211        | -19.364    | 0.019      || -152.097
# ...

# %%
SA.plot_SI_ecm_figure_()
# Out:
# A 16
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1109000 ), total/n_lambdas ( 36966.667 )
# A 24
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 950000 ), total/n_lambdas ( 31666.667 )
# A 32
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 954000 ), total/n_lambdas ( 31800.0 )
# B 8
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1589000 ), total/n_lambdas ( 52966.667 )
# B 16
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1129500 ), total/n_lambdas ( 37650.0 )
# B 24
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 954000 ), total/n_lambdas ( 31800.0 )
# B 32
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 982500 ), total/n_lambdas ( 32750.0 )
# G 8
# n_lambdas (reached at black dot): 30 = 30
# ...

# %%
[SA.tabulate_pgm_result_by_model_(i) for i in range(SA.n_pgm_versions_involved)];
# Out:
# PGM (mode version /mol) lattice FE estimates:
#
# form       | n_mol      | cell       | FE /kT     | SE /kT     | SD /kT     || S /k
# ========== | ========== | ========== | ========== | ========== | ========== || ==========
# A          | 16         | 222        | -19.353    | 0.01       | 0.01       || -153.41
# A          | 24         | 223        | -19.03     | 0.021      | 0.021      || -153.889
# A          | 32         | 224        | -18.942    | 0.024      | 0.024      || -153.998
# ---------- | ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# B          | 8          | 212        | -19.34     | 0.008      | 0.007      || -152.596
# B          | 16         | 222        | -18.831    | 0.009      | 0.009      || -153.202
# B          | 24         | 223        | -18.544    | 0.017      | 0.016      || -153.502
# B          | 32         | 224        | -18.451    | 0.008      | 0.008      || -153.568
# ...

# %%
[SA.plot_maintext_plot_by_model_(i) for i in range(SA.n_pgm_versions_involved)];

# %%
[SA.plot_SI_pgm_figure_by_model_(i) for i in range(SA.n_pgm_versions_involved)];

# %%
SA.plot_SI_pgm_energy_overlaps_(no_T=True)

# %% [markdown]
# # Veliparib (VEL)

# %%
# template of the main scripts in one of the systems:

form = 'I'
n_mol = 16

Next = 140

print(VEL.script_NPT_(form,n_mol)  +'\n'+'#'*Next)
print(VEL.script_NVT_(form,n_mol)  +'\n'+'#'*Next)
print(VEL.script_ECM_(form,n_mol)  +'\n'+'#'*Next)
print(VEL.script_PGM_(form,n_mol)  +'\n'+'#'*Next)
# Out:
#         from .O.MM.sc_system import *
#
#         # NPT script (equilibrating the ideal supercell to the forcefield):
#         # this is part of a loop, but more clear to write here as a single example
#
#         print('starting:', I, 121)
#         try:
#             PDB_unitcell = './O/MM/GAFF_sc/veliparib/veliparib_I_unitcell.pdb'
#             PDB_supercell = supercell_from_unitcell_(PDB_unitcell, cell=[1, 2, 1], save_output=True)[-1]
#             sc = SingleComponent(PDB = str(PDB_supercell), n_atoms_mol=34, name='veliparib', FF_name='GAFF')
#             sc.initialise_system_(PME_cutoff=0.36, nonbondedMethod=app.PME)
#             sc.initialise_simulation_(timestep_ps = 0.002, # ps
#                                     P = 1,               # atm
#                                     T = 300,             # K
#                                     barostat_type = 2,   # fully flexible
#                                     minimise = True,
# ...

# %%
VEL.tabulate_ecm_BAR_result_()
VEL.tabulate_ecm_MBAR_result_()
# Out:
# ECM lattice FE estimates based on BAR:
#
# form       | n_mol      | cell       | FE /kT     | SE /kT     || S /k
# ========== | ========== | ========== | ========== | ========== || ==========
# I          | 8          | 111        | 357.606    | 0.045      || -387.447
# I          | 16         | 121        | 358.289    | 0.046      || -388.572
# I          | 24         | 131        | 358.444    | 0.04       || -388.739
# I          | 32         | 221        | 358.74     | 0.141      || -389.131
# ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# II         | 9          | 131        | 355.639    | 0.046      || -388.099
# II         | 12         | 221        | 356.059    | 0.046      || -388.717
# II         | 18         | 321        | 356.319    | 0.046      || -388.828
# II         | 24         | 222        | 356.384    | 0.059      || -388.819
# II         | 27         | 331        | 356.523    | 0.046      || -388.994
# ...

# %%
VEL.plot_SI_ecm_figure_()
# Out:
# I 8
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1431000 ), total/n_lambdas ( 47700.0 )
# I 16
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1473500 ), total/n_lambdas ( 49116.667 )
# I 24
# n_lambdas (reached at black dot): 37 = 37
# number of MD frames (datapoints); total ( 2081500 ), total/n_lambdas ( 56256.757 )
# I 32
# n_lambdas (reached at black dot): 47 = 47
# number of MD frames (datapoints); total ( 1883500 ), total/n_lambdas ( 40074.468 )
# II 9
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1268500 ), total/n_lambdas ( 42283.333 )
# II 12
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1301500 ), total/n_lambdas ( 43383.333 )
# II 18
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1737000 ), total/n_lambdas ( 57900.0 )
# II 24
# ...

# %%
[VEL.tabulate_pgm_result_by_model_(i) for i in range(VEL.n_pgm_versions_involved)];
# Out:
# PGM (mode version /mol) lattice FE estimates:
#
# form       | n_mol      | cell       | FE /kT     | SE /kT     | SD /kT     || S /k
# ========== | ========== | ========== | ========== | ========== | ========== || ==========
# I          | 8          | 111        | 357.723    | 0.036      | 0.035      || -387.564
# I          | 16         | 121        | 358.365    | 0.064      | 0.056      || -388.648
# I          | 24         | 131        | 358.542    | 0.083      | 0.07       || -388.837
# I          | 32         | 221        | 358.79     | 0.088      | 0.065      || -389.18
# ---------- | ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# II         | 9          | 131        | 355.741    | 0.04       | 0.04       || -388.201
# II         | 12         | 221        | 356.141    | 0.051      | 0.043      || -388.799
# II         | 18         | 321        | 356.384    | 0.073      | 0.062      || -388.892
# ...

# %%
[VEL.plot_maintext_plot_by_model_(i) for i in range(VEL.n_pgm_versions_involved)];

# %%
[VEL.plot_SI_pgm_figure_by_model_(i) for i in range(VEL.n_pgm_versions_involved)];

# %%
VEL.plot_SI_pgm_energy_overlaps_(no_T=True)

# %% [markdown]
# # Mivebresib (MIV)

# %%
# template of the main scripts in one of the systems:

form = 'I'
n_mol = 16

Next = 140

print(MIV.script_NPT_(form,n_mol)  +'\n'+'#'*Next)
print(MIV.script_NVT_(form,n_mol)  +'\n'+'#'*Next)
print(MIV.script_ECM_(form,n_mol)  +'\n'+'#'*Next)
print(MIV.script_PGM_(form,n_mol)  +'\n'+'#'*Next)
# Out:
#         from .O.MM.sc_system import *
#
#         # NPT script (equilibrating the ideal supercell to the forcefield):
#         # this is part of a loop, but more clear to write here as a single example
#
#         print('starting:', I, 121)
#         try:
#             PDB_unitcell = './O/MM/GAFF_sc/mivebresib/mivebresib_I_unitcell.pdb'
#             PDB_supercell = supercell_from_unitcell_(PDB_unitcell, cell=[1, 2, 1], save_output=True)[-1]
#             sc = SingleComponent(PDB = str(PDB_supercell), n_atoms_mol=51, name='mivebresib', FF_name='GAFF')
#             sc.initialise_system_(PME_cutoff=0.36, nonbondedMethod=app.PME)
#             sc.initialise_simulation_(timestep_ps = 0.002, # ps
#                                     P = 1,               # atm
#                                     T = 300,             # K
#                                     barostat_type = 2,   # fully flexible
#                                     minimise = True,
# ...

# %%
MIV.tabulate_ecm_BAR_result_()
MIV.tabulate_ecm_MBAR_result_()
# Out:
# ECM lattice FE estimates based on BAR:
#
# form       | n_mol      | cell       | FE /kT     | SE /kT     || S /k
# ========== | ========== | ========== | ========== | ========== || ==========
# I          | 8          | 111        | 376.457    | 0.063      || -583.572
# I          | 16         | 121        | 377.196    | 0.1        || -584.363
# ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# II         | 8          | 221        | 382.222    | 0.06       || -585.685
# II         | 16         | 222        | 382.456    | 0.095      || -586.161
# ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# IIIs       | 8          | 111        | 376.667    | 0.064      || -583.046
# IIIs       | 16         | 211        | 377.49     | 0.104      || -583.85
# ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# IIIb       | 8          | 111        | 376.591    | 0.064      || -581.656
# ...

# %%
MIV.plot_SI_ecm_figure_()
# Out:
# I 8
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1811109 ), total/n_lambdas ( 60370.3 )
# I 16
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1816000 ), total/n_lambdas ( 60533.333 )
# II 8
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1805000 ), total/n_lambdas ( 60166.667 )
# II 16
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1800000 ), total/n_lambdas ( 60000.0 )
# IIIs 8
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1804500 ), total/n_lambdas ( 60150.0 )
# IIIs 16
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1815000 ), total/n_lambdas ( 60500.0 )
# IIIb 8
# n_lambdas (reached at black dot): 30 = 30
# number of MD frames (datapoints); total ( 1804000 ), total/n_lambdas ( 60133.333 )
# IIIb 16
# ...

# %%
[MIV.tabulate_pgm_result_by_model_(i) for i in range(MIV.n_pgm_versions_involved)];
# Out:
# PGM (mode version /mol,4h) lattice FE estimates:
#
# form       | n_mol      | cell       | FE /kT     | SE /kT     | SD /kT     || S /k
# ========== | ========== | ========== | ========== | ========== | ========== || ==========
# I          | 8          | 111        | 376.739    | 0.167      | 0.167      || -583.854
# I          | 16         | 121        | 377.439    | 0.385      | 0.124      || -584.606
# ---------- | ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# II         | 8          | 221        | 382.463    | 0.11       | 0.102      || -585.926
# II         | 16         | 222        | 382.618    | 0.193      | 0.111      || -586.323
# ---------- | ---------- | ---------- | ---------- | ---------- | ---------- || ----------
# IIIs       | 8          | 111        | 376.935    | 0.19       | 0.187      || -583.315
# IIIs       | 16         | 211        | 377.705    | 0.145      | 0.145      || -584.065
# ...

# %%
[MIV.plot_maintext_plot_by_model_(i) for i in range(MIV.n_pgm_versions_involved)];

# %%
[MIV.plot_SI_pgm_figure_by_model_(i) for i in range(MIV.n_pgm_versions_involved)];

# %%
MIV.plot_SI_pgm_energy_overlaps_(no_T=True)
